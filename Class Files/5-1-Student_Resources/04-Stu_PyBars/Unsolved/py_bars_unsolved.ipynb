# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities,alpha=.5,align='center')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_loc = [value for value in x_axis]
plt.xticks(tick_loc,cities)
# Out:
# ([<matplotlib.axis.XTick at 0x7fd4cb0251d0>,
#   <matplotlib.axis.XTick at 0x7fd4cb025c10>,
#   <matplotlib.axis.XTick at 0x7fd4caf99610>,
#   <matplotlib.axis.XTick at 0x7fd4cb055150>,
#   <matplotlib.axis.XTick at 0x7fd4cb0550d0>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-1,len(x_axis))
# Out:
# (-1.0, 5.0)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+1)
# Out:
# (0.0, 9.6)

# %%
# Give the chart a title, x label, and y label
bars_in_cities = [7,7, 7, 7, 7]
bars_in_cities
# Out:
# [7, 7, 7, 7, 7]

# %%
# Save an image of the chart and print it to the screen
plt.ylabel("Cities")
# Out:
# Text(55.847222222222214, 0.5, 'Cities')

# %%
plt.ylabel("Cities yay")
# Out:
# Text(55.847222222222214, 0.5, 'Cities yay')
